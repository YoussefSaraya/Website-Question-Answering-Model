# %%
pip install requests beautifulsoup4 lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\omars\appdata\roaming\python\python311\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import time
import csv
import logging
from urllib.parse import urljoin
import json # Keep for potential future use if needed, but not for primary output
import re

# --- Configuration ---
LOG_FILE = 'scraper_flattened.log'
OUTPUT_CSV_FILE = 'egypt_institutions_programs_flattened.csv'
LIST_PAGE_URL = "https://study-in-egypt.gov.eg/categories/All"

HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'
}
REQUEST_DELAY = 3 # Politeness delay

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - [%(funcName)s] %(message)s',
    handlers=[
        logging.FileHandler(LOG_FILE, mode='w', encoding='utf-8'),
        logging.StreamHandler()
    ]
)
# --- End Configuration ---

def get_detail_page_links(list_url):
    """
    Scrapes list page for name, detail URL, location, and category.
    Returns list of dicts: [{'name': '...', 'detail_url': '...', 'location': '...', 'category': '...'}]
    """
    institution_data_list = []
    logging.info(f"Fetching list page: {list_url}")
    try:
        response = requests.get(list_url, headers=HEADERS, timeout=60)
        response.raise_for_status()
        response.encoding = response.apparent_encoding
        soup = BeautifulSoup(response.content, 'lxml')

        institution_cards = soup.find_all('div', class_='gird_with_list')
        logging.info(f"Found {len(institution_cards)} cards on the list page.")

        if not institution_cards:
            logging.warning("No institution cards found. Check selector 'div.gird_with_list'.")
            return []

        for index, card in enumerate(institution_cards):
            card_data = {'name': 'N/A', 'detail_url': 'N/A', 'location': 'N/A', 'category': 'N/A'}

            # --- Extract Name and Detail URL ---
            link_element = card.select_one('div.caption h4.group a')
            if link_element:
                card_data['name'] = link_element.text.strip()
                relative_url = link_element.get('href')
                if relative_url:
                    card_data['detail_url'] = urljoin(response.url, relative_url)
            else:
                 logging.warning(f"Card {index+1}: Could not find name/link element.")
                 continue

            # --- Extract Location ---
            location_element = card.select_one('div.venue a')
            if location_element:
                card_data['location'] = ' '.join(location_element.text.split())
                logging.info(f"Card {index+1} ({card_data['name']}): Found Location: {card_data['location']}")
            else:
                logging.warning(f"Card {index+1} ({card_data['name']}): Location element 'div.venue a' not found.")

            # --- Extract Institution Category ---
            category_element = card.select_one('div.caption ul.list-inline li.tool-tip a')
            if category_element:
                 parent_li = category_element.find_parent('li')
                 if parent_li and parent_li.get('title', '').lower().endswith('category'):
                     card_data['category'] = category_element.text.strip()
                     logging.info(f"Card {index+1} ({card_data['name']}): Found Category: {card_data['category']}")
                 else:
                     first_li_link = card.select_one('div.caption ul.list-inline li a')
                     if first_li_link:
                         card_data['category'] = first_li_link.text.strip()
                         logging.info(f"Card {index+1} ({card_data['name']}): Found Category (Fallback): {card_data['category']}")
            else:
                 logging.warning(f"Card {index+1} ({card_data['name']}): Category element ('li.tool-tip a') not found.")

            institution_data_list.append(card_data)

        logging.info(f"Extracted initial data for {len(institution_data_list)} institutions from list page.")
        return institution_data_list

    except requests.exceptions.Timeout: logging.error(f"Timeout fetching list page: {list_url}"); return []
    except requests.exceptions.RequestException as e: logging.error(f"Request failed for list page {list_url}: {e}"); return []
    except Exception as e: logging.error(f"Error parsing list page {list_url}: {e}", exc_info=True); return []


def parse_program_table(table_soup, category_title, faculty_name):
    """Parses the program table within a faculty accordion item."""
    programs = []
    if not table_soup: return programs
    headers_raw = [th.text.strip().lower() for th in table_soup.select('thead th')]
    tbody = table_soup.find('tbody')
    if not tbody: return programs

    # Simple header cleaning (remove extra spaces, maybe handle minor variations)
    headers = [' '.join(h.split()) for h in headers_raw]

    # Map headers to consistent keys
    header_map = {
        'name': 'Program Name',
        'description': 'Program Description',
        'years of study': 'Years Of Study',
        'min. study years': 'Years Of Study', # Map variations to the same key
        'number of semesters': 'Number Of Semesters',
        'number of semesters in egypt': 'Number Of Semesters', # Map variations
        'fee in usd': 'Fee In USD',
        'fee in egp': 'Fee In EGP',
        'prerequisites': 'Prerequisites',
        'credit hours': 'Credit Hours',
        'max. study years': 'Max Study Years',
        'affiliated universities': 'Affiliated Universities',
        'number of semesters abroad': 'Semesters Abroad',
        # Add other headers you expect here
    }

    # Find column indices based on cleaned headers
    col_indices = {header_map.get(h): i for i, h in enumerate(headers) if h in header_map}
    # Ensure we have a name column index at least
    if 'Program Name' not in col_indices:
         logging.warning(f"Could not find 'Name' column header in table for {faculty_name} under {category_title}. Headers found: {headers}")
         # Attempt to use the first column as name as a fallback
         if headers: col_indices['Program Name'] = 0
         else: return [] # Cannot proceed without headers/columns


    rows = tbody.find_all('tr')
    for row in rows:
        cells = row.find_all('td')
        if not cells: continue

        prog_data = {
            'Program Category': category_title,
            'Faculty': faculty_name
        }
        num_cells = len(cells)
        num_headers = len(headers)

        # Try to extract data based on mapped indices
        for key, index in col_indices.items():
            # Basic handling for potential colspan issues - if cell count is less than header count assume mismatch
            # A more robust solution would inspect actual colspan attributes if needed
            effective_index = index
            if num_cells < num_headers and index > 0:
                # Simplistic check: if description likely had colspan, shift subsequent indices
                # Requires knowing which column typically has colspan (often description)
                desc_index = col_indices.get('Program Description', -1)
                if desc_index != -1 and index > desc_index:
                     effective_index = index - (num_headers - num_cells) # Adjust by difference

            if 0 <= effective_index < num_cells:
                prog_data[key] = cells[effective_index].text.strip()
            else:
                prog_data[key] = 'N/A' # Index out of bounds

        # Ensure essential program name is not empty
        if prog_data.get('Program Name', 'N/A') != 'N/A' and prog_data.get('Program Name'):
             programs.append(prog_data)
        else:
             logging.debug(f"Skipping row in {faculty_name} - likely missing program name. Cells: {[c.text.strip() for c in cells]}")


    return programs


def scrape_detail_page(institution_list_data):
    """
    Scrapes detail page.
    Returns a LIST of dictionaries, one for each program found.
    If no programs, returns a list with one dictionary containing only university details.
    """
    detail_url = institution_list_data.get('detail_url', 'N/A')
    output_rows = [] # This function will now return a list of rows

    # --- Initialize Base University Details ---
    base_details = {
        'Name': institution_list_data.get('name', 'N/A'),
        'Detail Page URL': detail_url,
        'Location': institution_list_data.get('location', 'N/A'),
        'Category': institution_list_data.get('category', 'N/A'),
        'Year Built': 'N/A',
        'Email': 'N/A',
        'Description': 'N/A',
        'Phone': 'N/A',
        'Coordinator': 'N/A',
        'Amenities': 'N/A',
        'Logo URL': 'N/A' # Neglecting logo for now based on previous request
    }
    # Program specific fields (will be filled later per program)
    program_fields = {
        'Program Category': 'N/A',
        'Faculty': 'N/A',
        'Program Name': 'N/A',
        'Program Description': 'N/A',
        'Years Of Study': 'N/A',
        'Number Of Semesters': 'N/A',
        'Fee In USD': 'N/A',
        'Fee In EGP': 'N/A',
        'Prerequisites': 'N/A',
        'Credit Hours': 'N/A',
        'Max Study Years': 'N/A',
        'Affiliated Universities': 'N/A',
        'Semesters Abroad': 'N/A',
    }


    if detail_url == 'N/A':
         logging.error(f"Missing detail_url for name '{base_details['Name']}'. Cannot scrape.")
         # Return a single row with base details and errors in program fields
         error_row = base_details.copy()
         error_row.update({k: 'Error: Missing Detail URL' for k in program_fields})
         output_rows.append(error_row)
         return output_rows

    logging.info(f"Scraping detail page for {base_details['Name']}: {detail_url}")

    try:
        logging.debug(f"Waiting {REQUEST_DELAY} seconds...")
        time.sleep(REQUEST_DELAY)

        response = requests.get(detail_url, headers=HEADERS, timeout=60)
        response.raise_for_status()
        response.encoding = response.apparent_encoding
        soup = BeautifulSoup(response.content, 'lxml')

        # --- Scrape Base University Details from Detail Page ---
        # Name (Confirm/update)
        name_element_h1 = soup.find('h1'); name_element_strong = soup.select_one('div.page-title strong')
        confirmed_name = None
        if name_element_h1: confirmed_name = name_element_h1.text.strip()
        elif name_element_strong: confirmed_name = name_element_strong.text.strip()
        if confirmed_name and confirmed_name != base_details['Name']:
             logging.info(f"Updated name from '{base_details['Name']}' to '{confirmed_name}'.")
             base_details['Name'] = confirmed_name
        else: logging.info(f"Name '{base_details['Name']}' confirmed.")

        # Email
        email_element = soup.select_one('li.track-me a[href^="mailto:"]')
        if email_element: base_details['Email'] = email_element.text.strip(); logging.info(f"Found Email: {base_details['Email']}")
        else: base_details['Email'] = 'Not Found'; logging.info(f"Email not found.")

        # Phone
        phone_element = soup.select_one('a[href^="tel:"]')
        if phone_element: base_details['Phone'] = phone_element.text.strip(); logging.info(f"Found Phone: {base_details['Phone']}")
        else: base_details['Phone'] = 'Not Found'; logging.info(f"Phone not found.")

        # Year Built
        contact_links_year = soup.select('span a, div a'); found_year = False
        for link in contact_links_year:
            link_text = link.text.strip()
            if link_text.lower().startswith('year build:'):
                 year_match = re.search(r'\d{4}', link_text)
                 if year_match: base_details['Year Built'] = year_match.group(0); found_year = True; logging.info(f"Found Year Built: {base_details['Year Built']}"); break
        if not found_year: base_details['Year Built'] = 'Not Found'; logging.info("Year Built not found.")

        # Coordinator
        contact_links_coord = soup.select('a'); found_coordinator = False
        for link in contact_links_coord:
            link_text = link.text.strip()
            if link_text.startswith('Coordinator:'): base_details['Coordinator'] = link_text.replace('Coordinator:', '').strip(); found_coordinator = True; logging.info(f"Found Coordinator: {base_details['Coordinator']}"); break
        if not found_coordinator: base_details['Coordinator'] = 'Not Found'; logging.info(f"Coordinator not found.")

        # Amenities
        amenities_list = []
        amenities_panel_ul = soup.select_one('div.panel-body > ul')
        if amenities_panel_ul:
            list_items = amenities_panel_ul.find_all('li', recursive=False)
            if list_items:
                for item in list_items: text = ' '.join(item.text.split()).strip();
                if text: amenities_list.append(text)
                base_details['Amenities'] = "\n".join(amenities_list); logging.info(f"Found {len(amenities_list)} amenities.")
            else: base_details['Amenities'] = 'None Listed'; logging.info(f"Amenities section empty.")
        else: base_details['Amenities'] = 'Not Found'; logging.info(f"Amenities section not found.")

        # Description
        description_panel = None; all_panels = soup.select('div.panel-body')
        for panel in all_panels:
            has_amenities_ul = panel.select_one(':scope > ul') is not None; has_row_div = panel.select_one(':scope > div.row') is not None; has_direct_text = any(isinstance(c, str) and c.strip() for c in panel.contents)
            if not has_amenities_ul and (has_row_div or has_direct_text): description_panel = panel; break
        if description_panel:
            inner_div = description_panel.select_one('div.row > div'); desc_text = ''
            if inner_div: desc_text = ' '.join(inner_div.text.split())
            if not desc_text: desc_text = ' '.join(description_panel.text.split())
            if desc_text: base_details['Description'] = desc_text; logging.info(f"Found Description.")
            else: base_details['Description'] = 'None Provided'; logging.info(f"Description panel empty.")
        else: base_details['Description'] = 'Not Found'; logging.info(f"Description panel structure not found.")

        # Neglecting Logo based on previous request
        base_details['Logo URL'] = 'Not Scraped'

        # --- Scrape Programs/Departments ---
        logging.info("Extracting programs...")
        all_programs_data = []
        main_accordion_list = soup.select_one('ul.accordion__list')
        if main_accordion_list:
            category_items = main_accordion_list.select(':scope > li.accordion__item')
            logging.info(f"Found {len(category_items)} main program categories.")
            for category_item in category_items:
                category_title_element = category_item.select_one(':scope > .accordion__itemTitleWrap > h3.accordion__itemTitle')
                category_title = category_title_element.text.strip() if category_title_element else "Unknown Category"
                logging.info(f"Processing Category: {category_title}")
                faculty_list = category_item.select_one(':scope > .accordion__itemContent > ul.accordion__list')
                if faculty_list:
                    faculty_items = faculty_list.select(':scope > li.accordion__item')
                    logging.debug(f"Found {len(faculty_items)} faculties under {category_title}")
                    for faculty_item in faculty_items:
                        faculty_title_element = faculty_item.select_one(':scope > .accordion__itemTitleWrap h3.accordion__itemTitle')
                        faculty_name = faculty_title_element.text.strip() if faculty_title_element else "Unknown Faculty"
                        faculty_name = faculty_name.replace("Faculty of", "").strip()
                        logging.debug(f"--> Processing Faculty: {faculty_name}")
                        program_table = faculty_item.select_one(':scope > .accordion__itemContent table')
                        if program_table:
                             faculty_programs = parse_program_table(program_table, category_title, faculty_name)
                             if faculty_programs:
                                 logging.debug(f"    Parsed {len(faculty_programs)} programs for {faculty_name}")
                                 all_programs_data.extend(faculty_programs)
                             else: logging.debug(f"    Table found for {faculty_name}, but no programs parsed.")
                        else: logging.debug(f"    No program table found for {faculty_name}")
                else: logging.debug(f"No faculty list under category: {category_title}")
        else: logging.warning("Main program accordion list not found.")

        # --- Combine Base Details with Each Program ---
        if all_programs_data:
            logging.info(f"Found {len(all_programs_data)} total programs. Creating flattened rows...")
            for program_data in all_programs_data:
                row = base_details.copy() # Start with university info
                row.update(program_data)  # Add program specific info
                output_rows.append(row)
        else:
            # If no programs found, add one row with only base university details
            logging.info("No programs found for this university. Adding single row with base details.")
            row = base_details.copy()
            row.update(program_fields) # Add program field keys with N/A values
            output_rows.append(row)

        logging.info(f"Finished processing detail page for: {base_details['Name']}")
        return output_rows

    except requests.exceptions.Timeout: error_msg = 'Error: Request Timeout'
    except requests.exceptions.RequestException as e: error_msg = f'Error: HTTP Request Failed ({e})'
    except Exception as e: error_msg = f'Error: Parsing Failed ({e})'; logging.error(f"Error parsing detail page {detail_url}: {e}", exc_info=True)

    logging.error(f"{error_msg} while scraping detail page {detail_url}")
    # If an exception occurred, return a single row with error messages
    error_row = base_details.copy()
    error_row.update({k: error_msg for k in program_fields}) # Update program fields with error
    output_rows.append(error_row)
    return output_rows


def save_to_csv(data, filename):
    """Saves the flattened data list (of dictionaries) to a CSV file."""
    if not data:
        logging.warning("No data collected to save.")
        return

    # Define the order of columns in the CSV file - FLAT STRUCTURE
    fieldnames = [
        # University Details
        'Name', 'Category', 'Year Built', 'Description', 'Location', 'Phone', 'Email',
        'Coordinator', 'Amenities', 'Detail Page URL', 'Logo URL',
        # Program Details (prefixed for clarity, adjust if needed)
        'Program Category', 'Faculty', 'Program Name', 'Program Description',
        'Years Of Study', 'Number Of Semesters', 'Fee In USD', 'Fee In EGP',
        'Prerequisites', 'Credit Hours', 'Max Study Years',
        'Affiliated Universities', 'Semesters Abroad',
    ]
    logging.info(f"Attempting to save {len(data)} rows to {filename}")
    try:
        with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
            # Use extrasaction='ignore' in case some rows miss minor fields due to parsing variations
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames, extrasaction='ignore')
            writer.writeheader()
            writer.writerows(data)
        logging.info(f"Data successfully saved to {filename}")
    except IOError as e: logging.error(f"Could not write to CSV file {filename}: {e}")
    except Exception as e: logging.error(f"An unexpected error during CSV writing: {e}", exc_info=True)


# --- Main Execution ---
if __name__ == "__main__":
    logging.info("--- Scraper Started ---")

    # Step 1: Get initial data (incl. Location, Category) from list page
    institution_list_data = get_detail_page_links(LIST_PAGE_URL)

    all_flattened_rows = [] # Renamed list to reflect content
    if institution_list_data:
        total_institutions = len(institution_list_data)
        logging.info(f"Starting to scrape detail pages for {total_institutions} institutions...")
        # Step 2: Scrape details, getting back a list of rows per institution
        for i, initial_data in enumerate(institution_list_data):
            logging.info(f"--- Processing institution {i+1} of {total_institutions} ---")
            # scrape_detail_page now returns a list of program rows (or one base row)
            program_rows_list = scrape_detail_page(initial_data)
            # Use extend to add all rows from the list to the main list
            all_flattened_rows.extend(program_rows_list)
        logging.info(f"Finished scraping detail pages.")
    else:
        logging.warning("Did not find any institution data on the list page.")

    # Step 3: Save all collected flattened rows
    save_to_csv(all_flattened_rows, OUTPUT_CSV_FILE)

    logging.info("--- Scraper Finished ---")
# Out:
# 2025-04-21 15:10:05,761 - INFO - --- Scraper Started ---
# 2025-04-21 15:10:05,762 - INFO - Fetching list page: https://study-in-egypt.gov.eg/categories/All
# 2025-04-21 15:10:15,770 - INFO - Found 303 cards on the list page.
# 2025-04-21 15:10:15,773 - INFO - Card 1 (Cairo Higher Institute for Languages, Interpretation, Administrative Sciences and Computer - Mokattam): Found Location: Mokattam - the commercial station - 5 Street 54 Cairo Egypt
# 2025-04-21 15:10:15,774 - INFO - Card 1 (Cairo Higher Institute for Languages, Interpretation, Administrative Sciences and Computer - Mokattam): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,777 - INFO - Card 2 (Ain Shams University ASU): Found Location: El-Khalifa El-Maamoun Street, El-Abbassia, 11566 Cairo Egypt
# 2025-04-21 15:10:15,779 - INFO - Card 2 (Ain Shams University ASU): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,781 - INFO - Card 3 (Al Azhar University): Found Location: Autostrad Road, Nasr City Cairo Egypt
# 2025-04-21 15:10:15,782 - INFO - Card 3 (Al Azhar University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,784 - INFO - Card 4 (New Mansoura University NMU): Found Location:
# 2025-04-21 15:10:15,785 - INFO - Card 4 (New Mansoura University NMU): Found Category (Fallback): Community university
# 2025-04-21 15:10:15,788 - INFO - Card 5 (Heliopolis University - Sekem University): Found Location: 3 Cairo - Belbeis Desert Road, El-Nahda, Second Al Salam Cairo Egypt
# 2025-04-21 15:10:15,790 - INFO - Card 5 (Heliopolis University - Sekem University): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,792 - INFO - Card 6 (The American University in Cairo AUC): Found Location: Tahrir Square Cairo Egypt
# 2025-04-21 15:10:15,793 - INFO - Card 6 (The American University in Cairo AUC): Found Category (Fallback): International university
# 2025-04-21 15:10:15,796 - INFO - Card 7 (October University for Modern Sciences and Arts MSA): Found Location: 26 July Mehwar Road, Intersection with Wahat Road, 6th of October City Giza Egypt
# 2025-04-21 15:10:15,797 - INFO - Card 7 (October University for Modern Sciences and Arts MSA): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,799 - INFO - Card 8 (Egyptian Aviation Academy): Found Location:
# 2025-04-21 15:10:15,800 - INFO - Card 8 (Egyptian Aviation Academy): Found Category (Fallback): Academy
# 2025-04-21 15:10:15,802 - INFO - Card 9 (Senghor University in Alexandria): Found Location: Al-Mansheyah Al-Kubra Alexandria Egypt
# 2025-04-21 15:10:15,804 - INFO - Card 9 (Senghor University in Alexandria): Found Category (Fallback): International university
# 2025-04-21 15:10:15,806 - INFO - Card 10 (Ahram Canadian University ACU): Found Location: 6th of October City Giza Egypt
# 2025-04-21 15:10:15,807 - INFO - Card 10 (Ahram Canadian University ACU): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,810 - INFO - Card 11 (Technical Institute for Tourism and Hotels - Qena): Found Location: Qena Qena Egypt
# 2025-04-21 15:10:15,812 - INFO - Card 11 (Technical Institute for Tourism and Hotels - Qena): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:15,815 - INFO - Card 12 (Egyptian E-learning University EELU): Found Location: Al-Mesaha Street, Dokki Giza Egypt
# 2025-04-21 15:10:15,816 - INFO - Card 12 (Egyptian E-learning University EELU): Found Category (Fallback): Community university
# 2025-04-21 15:10:15,818 - INFO - Card 13 (Kafr El-Sheikh University): Found Location: El Geish Street Kafr El-Sheikh Egypt
# 2025-04-21 15:10:15,820 - INFO - Card 13 (Kafr El-Sheikh University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,821 - INFO - Card 14 (Al Jazeera Higher Institute for Media and Communication Sciences - Mokattam): Found Location: 73 of 9 Street in front of Al-Quds Mosque - High Plateau - Mokattam Cairo Egypt
# 2025-04-21 15:10:15,823 - INFO - Card 14 (Al Jazeera Higher Institute for Media and Communication Sciences - Mokattam): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,825 - INFO - Card 15 (Sadat Academy for Management Sciences SAMS): Found Location: Nile Corniche, Maadi Entrance No. (1) Cairo Egypt
# 2025-04-21 15:10:15,826 - INFO - Card 15 (Sadat Academy for Management Sciences SAMS): Found Category (Fallback): Academy
# 2025-04-21 15:10:15,829 - INFO - Card 16 (Commercial Technical Institute - Tanta): Found Location: Tutankhamun Street, Tanta (Division 2), Tanta, Gharbia Tanta Egypt
# 2025-04-21 15:10:15,830 - INFO - Card 16 (Commercial Technical Institute - Tanta): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:15,832 - INFO - Card 17 (King Salman International University KSIU): Found Location: King Salman International University, Al Tur South Sinai Egypt
# 2025-04-21 15:10:15,833 - INFO - Card 17 (King Salman International University KSIU): Found Category (Fallback): Community university
# 2025-04-21 15:10:15,835 - INFO - Card 18 (Al Madina Higher Institute for International Languages - Shbrament): Found Location: Saqqara Tourist road, Al-Haram Giza Egypt
# 2025-04-21 15:10:15,837 - INFO - Card 18 (Al Madina Higher Institute for International Languages - Shbrament): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,839 - INFO - Card 19 (Workers University): Found Location: 6 El-Nasr Road Corner, Abbas El-Akkad, Sixth Zone, Nasr City Cairo Egypt
# 2025-04-21 15:10:15,840 - INFO - Card 19 (Workers University): Found Category (Fallback): Technological university
# 2025-04-21 15:10:15,843 - INFO - Card 20 (Delta University for Science and Technology DU): Found Location: International Coastal Road, Al-Hafir and Al-Amal, Belkas Dakahlia Egypt
# 2025-04-21 15:10:15,844 - INFO - Card 20 (Delta University for Science and Technology DU): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,847 - INFO - Card 21 (Institute of Arab Research and Studies IARS): Found Location: 1 Arab Union Lawyers Street, Garden City Cairo Egypt
# 2025-04-21 15:10:15,848 - INFO - Card 21 (Institute of Arab Research and Studies IARS): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,850 - INFO - Card 22 (Institute of National Planning INP): Found Location: The Intersection of Salah Salem Street with Tayran Street, Nasr City Cairo Egypt
# 2025-04-21 15:10:15,852 - INFO - Card 22 (Institute of National Planning INP): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,854 - INFO - Card 23 (Badr University in Cairo BUC): Found Location: Cairo Suez Road, University Road, 11829 Cairo Egypt
# 2025-04-21 15:10:15,856 - INFO - Card 23 (Badr University in Cairo BUC): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,858 - INFO - Card 24 (Arab Open University AOU): Found Location: The Second District, El-Shrouk Cairo Egypt
# 2025-04-21 15:10:15,861 - INFO - Card 24 (Arab Open University AOU): Found Category (Fallback): International university
# 2025-04-21 15:10:15,863 - INFO - Card 25 (Fayoum University): Found Location: 32 Zaid Ibn-Haritha Street, Al-Mashtal Fayoum Egypt
# 2025-04-21 15:10:15,864 - INFO - Card 25 (Fayoum University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,866 - INFO - Card 26 (Al Alamein International University AIU): Found Location: Near Alexandria at El Alamein El Alamein Egypt
# 2025-04-21 15:10:15,867 - INFO - Card 26 (Al Alamein International University AIU): Found Category (Fallback): Community university
# 2025-04-21 15:10:15,869 - INFO - Card 27 (Mansoura University): Found Location: Elgomhouria St., Mansoura City, Dakahlia Mansoura Egypt
# 2025-04-21 15:10:15,870 - INFO - Card 27 (Mansoura University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,872 - INFO - Card 28 (Menoufia University): Found Location: Gamal Abdel-Nasser Street, Shebin Al-Kom Menoufia Egypt
# 2025-04-21 15:10:15,875 - INFO - Card 28 (Menoufia University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,877 - INFO - Card 29 (International Academy of Engineering and Media Sciences): Found Location: October 6 - Media Production City. Giza Egypt
# 2025-04-21 15:10:15,880 - INFO - Card 29 (International Academy of Engineering and Media Sciences): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,883 - INFO - Card 30 (Al Madina Higher Institute for Management and Technology - Shbrament): Found Location:
# 2025-04-21 15:10:15,886 - INFO - Card 30 (Al Madina Higher Institute for Management and Technology - Shbrament): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,888 - INFO - Card 31 (Higher Technological Institute - 6th of October Branch HTI): Found Location: October Branch: 6th of October - Third District - 7th Neighborhood. Giza Egypt
# 2025-04-21 15:10:15,890 - INFO - Card 31 (Higher Technological Institute - 6th of October Branch HTI): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,892 - INFO - Card 32 (Newgiza University NGU): Found Location: Km 22 Cairo - Alex Road, 12256 Giza Egypt
# 2025-04-21 15:10:15,894 - INFO - Card 32 (Newgiza University NGU): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,897 - INFO - Card 33 (The French University of Egypt UFE): Found Location: 21 Ismailia Desert Road, Shorouk City Cairo Egypt
# 2025-04-21 15:10:15,899 - INFO - Card 33 (The French University of Egypt UFE): Found Category (Fallback): Community university
# 2025-04-21 15:10:15,901 - INFO - Card 34 (ESLSCA Business School): Found Location: 6, El-Woroud Street, El-Mohandessin Giza Egypt
# 2025-04-21 15:10:15,904 - INFO - Card 34 (ESLSCA Business School): Found Category (Fallback): Academy
# 2025-04-21 15:10:15,906 - INFO - Card 35 (Modern University for Technology and Information MTI): Found Location: El-Hadaba El-Wosta, Mokattam, 5th District Cairo Egypt
# 2025-04-21 15:10:15,908 - INFO - Card 35 (Modern University for Technology and Information MTI): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,909 - INFO - Card 36 (Higher Institute for Administrative Sciences - Katameya): Found Location: The Higher Institute for Administrative Sciences in Katameya, Third Settlement, Mahmudiyah Residences Cairo
# 2025-04-21 15:10:15,911 - INFO - Card 36 (Higher Institute for Administrative Sciences - Katameya): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,913 - INFO - Card 37 (Higher Institute of Marketing, Trade and Information Systems - First Settlement): Found Location: Behind central of First Settlement New Cairo Egypt
# 2025-04-21 15:10:15,916 - INFO - Card 37 (Higher Institute of Marketing, Trade and Information Systems - First Settlement): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,919 - INFO - Card 38 (Pharos University in Alexandria PUA): Found Location: Canal Mahmoudiah Street, Ezbet El-Nozha, Sidi Gaber Alexandria Egypt
# 2025-04-21 15:10:15,921 - INFO - Card 38 (Pharos University in Alexandria PUA): Found Category (Fallback): Private university
# 2025-04-21 15:10:15,923 - INFO - Card 39 (Modern Academy for Engineering and Technology - Maadi): Found Location: El-Hadaba El-Wosta, ElMokattam, Close to Mokattam Central Cairo Egypt
# 2025-04-21 15:10:15,926 - INFO - Card 39 (Modern Academy for Engineering and Technology - Maadi): Found Category (Fallback): Academy
# 2025-04-21 15:10:15,929 - INFO - Card 40 (Cairo University): Found Location: University street, Orman, 12613 Giza Egypt
# 2025-04-21 15:10:15,931 - INFO - Card 40 (Cairo University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,934 - INFO - Card 41 (University of Sadat City): Found Location: Gamal Abdel Nasser Street, Sadat City Menofia Egypt
# 2025-04-21 15:10:15,936 - INFO - Card 41 (University of Sadat City): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,939 - INFO - Card 42 (Benha University): Found Location: Farid Nada Street, Benha Qalyubia Egypt
# 2025-04-21 15:10:15,940 - INFO - Card 42 (Benha University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,942 - INFO - Card 43 (Zagazig University): Found Location: Post number : 44519 - Zagazig Sharqia Egypt
# 2025-04-21 15:10:15,945 - INFO - Card 43 (Zagazig University): Found Category (Fallback): Public university
# 2025-04-21 15:10:15,947 - INFO - Card 44 (Higher Institute of Applied Arts): Found Location: First District - Second Neighborhood - 6th of October. Giza Egypt
# 2025-04-21 15:10:15,949 - INFO - Card 44 (Higher Institute of Applied Arts): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,952 - INFO - Card 45 (Higher Institute of Engineering and Modern Technology - Al-Marg): Found Location: The Ring Road, New Marg Cairo Egypt
# 2025-04-21 15:10:15,954 - INFO - Card 45 (Higher Institute of Engineering and Modern Technology - Al-Marg): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,957 - INFO - Card 46 (The Intermediate Institute for Social Service - Kafr El Sheikh): Found Location: Formerly King Fouad Palace - El Geish Street Kafr El Sheikh Egypt
# 2025-04-21 15:10:15,959 - INFO - Card 46 (The Intermediate Institute for Social Service - Kafr El Sheikh): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,964 - INFO - Card 47 (Higher Institute of Computers, Information and Management Technology - Tanta): Found Location: Tanta - Highway - next to the stores of Abdel Dayem and Radio in the middle of the old delta - A second section Al Gharbia Egypt
# 2025-04-21 15:10:15,967 - INFO - Card 47 (Higher Institute of Computers, Information and Management Technology - Tanta): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,968 - INFO - Card 48 (Higher Technological Institute - Matrouh Branch HTI): Found Location: Matrouh Branch: Marsa Matrouh, next to the College of Education. Marsa Matrouh Egypt
# 2025-04-21 15:10:15,969 - INFO - Card 48 (Higher Technological Institute - Matrouh Branch HTI): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,970 - INFO - Card 49 (Akhbar El Youm Academy): Found Location: Industrial Fourth Area, 6th of October City Giza Egypt
# 2025-04-21 15:10:15,972 - INFO - Card 49 (Akhbar El Youm Academy): Found Category (Fallback): Academy
# 2025-04-21 15:10:15,974 - INFO - Card 50 (Higher Institute of Engineering and Technology - Tanta): Found Location: Mahala Village Street, 8 Shoubra Al-Namlah - Tanta Al Gharbia Egypt
# 2025-04-21 15:10:15,977 - INFO - Card 50 (Higher Institute of Engineering and Technology - Tanta): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,979 - INFO - Card 51 (Higher Institute of Engineering and Technology - Al-Tud Luxor): Found Location: Tod, New Tod, Luxor Luxor Egypt
# 2025-04-21 15:10:15,982 - INFO - Card 51 (Higher Institute of Engineering and Technology - Al-Tud Luxor): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,983 - INFO - Card 52 (Zewail City of Science and Technology): Found Location: Plot 12578, Ahmed Zewail Road, October Gardens, 6th of October City Giza Egypt
# 2025-04-21 15:10:15,986 - INFO - Card 52 (Zewail City of Science and Technology): Found Category (Fallback): Technological university
# 2025-04-21 15:10:15,989 - INFO - Card 53 (October Higher Institute of Economics - 6th of October): Found Location: City of Culture and Science - Block No. 3/51 AB - Central Axis - The eleventh district Giza Egypt
# 2025-04-21 15:10:15,991 - INFO - Card 53 (October Higher Institute of Economics - 6th of October): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,992 - INFO - Card 54 (Higher Institute of Engineering and Technology - Kafr El Sheikh): Found Location: Al-Taifa Kafr El-Sheikh Egypt
# 2025-04-21 15:10:15,996 - INFO - Card 54 (Higher Institute of Engineering and Technology - Kafr El Sheikh): Found Category (Fallback): High institute
# 2025-04-21 15:10:15,998 - INFO - Card 55 (Higher Institute of Engineering and Technology - King Mariout): Found Location: Behind the free zone - Al Kafoury road, Kilo 31 Desert Road Alexandria Egypt
# 2025-04-21 15:10:16,001 - INFO - Card 55 (Higher Institute of Engineering and Technology - King Mariout): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,003 - INFO - Card 56 (University of Canada - University of Prince Edward Island UPEI): Found Location: Cairo Egypt
# 2025-04-21 15:10:16,006 - INFO - Card 56 (University of Canada - University of Prince Edward Island UPEI): Found Category (Fallback): International university
# 2025-04-21 15:10:16,008 - INFO - Card 57 (German University in Cairo GUC): Found Location: New Cairo City, main entrance of Fifth Settlement Cairo Egypt
# 2025-04-21 15:10:16,009 - INFO - Card 57 (German University in Cairo GUC): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,011 - INFO - Card 58 (Higher Institute of Tourism and Hotels): Found Location: October 6 - the sixth district - the tenth neighborhood. Giza Egypt
# 2025-04-21 15:10:16,013 - INFO - Card 58 (Higher Institute of Tourism and Hotels): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,016 - INFO - Card 59 (Higher Institute of Engineering and Technology - New Minya): Found Location: Bani Muhammad Sharawi, Abu Qurqas Minya Egypt
# 2025-04-21 15:10:16,018 - INFO - Card 59 (Higher Institute of Engineering and Technology - New Minya): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,020 - INFO - Card 60 (Higher Institute of Social Service - Sohag): Found Location: Salamouni, Akhmim Sohag Center Sohag Egypt
# 2025-04-21 15:10:16,022 - INFO - Card 60 (Higher Institute of Social Service - Sohag): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,025 - INFO - Card 61 (Helwan University): Found Location: Chemin de Fer de l'Ouest, Logement Économique, Helwan Cairo Egypt
# 2025-04-21 15:10:16,027 - INFO - Card 61 (Helwan University): Found Category (Fallback): Public university
# 2025-04-21 15:10:16,031 - INFO - Card 62 (October Higher Institute of Engineering and Technology): Found Location: October 6 - the second neighborhood, the second neighborhood - in front of the new police building. Giza Egypt
# 2025-04-21 15:10:16,034 - INFO - Card 62 (October Higher Institute of Engineering and Technology): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,038 - INFO - Card 63 (Academy of Arts): Found Location: Gamal El-Din El-Afghany Street, Haram Road Giza Egypt
# 2025-04-21 15:10:16,041 - INFO - Card 63 (Academy of Arts): Found Category (Fallback): Academy
# 2025-04-21 15:10:16,044 - INFO - Card 64 (Nile University NU): Found Location: 26th of July Corridor, Al-Sheikh Zayed Giza Egypt
# 2025-04-21 15:10:16,048 - INFO - Card 64 (Nile University NU): Found Category (Fallback): Community university
# 2025-04-21 15:10:16,052 - INFO - Card 65 (The Arab Academy for Management, Banking and Financial Sciences AAMBFS): Found Location: 8 Fawakeh Street, Mohandessin, Dokki Giza Egypt
# 2025-04-21 15:10:16,055 - INFO - Card 65 (The Arab Academy for Management, Banking and Financial Sciences AAMBFS): Found Category (Fallback): Academy
# 2025-04-21 15:10:16,058 - INFO - Card 66 (Higher Institute for Administrative Sciences - Sohag): Found Location: Kawther, Salmoni, Akhmim Center, Sohag Sohag Egypt
# 2025-04-21 15:10:16,061 - INFO - Card 66 (Higher Institute for Administrative Sciences - Sohag): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,065 - INFO - Card 67 (Misr University for Science & Technology MUST): Found Location: First 6th of October Giza Egypt
# 2025-04-21 15:10:16,067 - INFO - Card 67 (Misr University for Science & Technology MUST): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,073 - INFO - Card 68 (Thebes Higher Institute for Computer and Administrative Sciences - Maadi, Cairo): Found Location: The first of Maadi Corniche, behind the Nile Badrawi Hospital Cairo Egypt
# 2025-04-21 15:10:16,076 - INFO - Card 68 (Thebes Higher Institute for Computer and Administrative Sciences - Maadi, Cairo): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,079 - INFO - Card 69 (Deraya University): Found Location: Plot no. 3 El Gameaat Land New Minya Egypt
# 2025-04-21 15:10:16,083 - INFO - Card 69 (Deraya University): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,087 - INFO - Card 70 (Higher Technological Institute - 10th of Ramadan HTI): Found Location: 10th of Ramadan City - next to the Small Industries Complex. " Sharqeya Egypt
# 2025-04-21 15:10:16,090 - INFO - Card 70 (Higher Technological Institute - 10th of Ramadan HTI): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,094 - INFO - Card 71 (The Higher Institute for Tourism and Hotels in Ismailia (EGOTH)): Found Location: Al-Blajat Road - next to Al-Nawras Village - Abdel-Moneim Amara Road Ismailia Egypt
# 2025-04-21 15:10:16,097 - INFO - Card 71 (The Higher Institute for Tourism and Hotels in Ismailia (EGOTH)): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,100 - INFO - Card 72 (Assiut University): Found Location: Assiut University, 71515 Assiut Egypt
# 2025-04-21 15:10:16,104 - INFO - Card 72 (Assiut University): Found Category (Fallback): Public university
# 2025-04-21 15:10:16,107 - INFO - Card 73 (National Telecommunication Institute NTI): Found Location: KM 28, Cairo - Alexandria Desert Road, Building B147, Smart Village Cairo Egypt
# 2025-04-21 15:10:16,110 - INFO - Card 73 (National Telecommunication Institute NTI): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,114 - INFO - Card 74 (Higher Institute of Languages - Heliopolis): Found Location: Higher Institute of Languages, end of El-Nozha Metro, behind Sheraton Residence, Heliopolis, Cairo Cairo Egypt
# 2025-04-21 15:10:16,116 - INFO - Card 74 (Higher Institute of Languages - Heliopolis): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,118 - INFO - Card 75 (The Intermediate Institute for Social Service - Alexandria): Found Location: 55 El Horreya Road (previously Fouad) Alexandria Egypt
# 2025-04-21 15:10:16,120 - INFO - Card 75 (The Intermediate Institute for Social Service - Alexandria): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,122 - INFO - Card 76 (Higher Institute of Computer - King Mariout, Alexandria): Found Location: Behind the free zone - Al Kafoury road, Kilo 31 Desert Road Alexandria Egypt
# 2025-04-21 15:10:16,125 - INFO - Card 76 (Higher Institute of Computer - King Mariout, Alexandria): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,126 - INFO - Card 77 (Egyptian-Russian University ERU): Found Location: Cairo - Suez road, Badr City Cairo Egypt
# 2025-04-21 15:10:16,127 - INFO - Card 77 (Egyptian-Russian University ERU): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,130 - INFO - Card 78 (Canadian Higher Institute of Technology, Engineering and Management - Fifth Settlement CIC): Found Location: Land # 6, Center Services, south of Police Academy, Fifth Settlement New Cairo Egypt
# 2025-04-21 15:10:16,131 - INFO - Card 78 (Canadian Higher Institute of Technology, Engineering and Management - Fifth Settlement CIC): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,133 - INFO - Card 79 (Egyptian Chinese University ECU): Found Location: 14 Abou Ghazalh, Mansheya El-Tahrir, Ein Shams Cairo Egypt
# 2025-04-21 15:10:16,135 - INFO - Card 79 (Egyptian Chinese University ECU): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,137 - INFO - Card 80 (The British University in Egypt BUE): Found Location: Suez Desert Road, El-Sherouk City, 11837 Cairo Egypt
# 2025-04-21 15:10:16,139 - INFO - Card 80 (The British University in Egypt BUE): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,141 - INFO - Card 81 (International Higher Institute of Media - El Shorouk City): Found Location: Palm suburb - Shorouk City- the Suez Road Cairo Egypt
# 2025-04-21 15:10:16,144 - INFO - Card 81 (International Higher Institute of Media - El Shorouk City): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,147 - INFO - Card 82 (Higher Institute of Engineering - El Shorouk): Found Location: Palm suburb - the city of sunrise - Suez Road Cairo Egypt
# 2025-04-21 15:10:16,149 - INFO - Card 82 (Higher Institute of Engineering - El Shorouk): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,151 - INFO - Card 83 (Higher Institute of Administrative Sciences - Eastern Belbeis): Found Location: Saadat, Belbeis Center Al Sharkia Egypt
# 2025-04-21 15:10:16,153 - INFO - Card 83 (Higher Institute of Administrative Sciences - Eastern Belbeis): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,153 - INFO - Card 84 (The Higher Institute for Tourism, Hotels and Monuments Restoration - Abo Kir, Alexandria): Found Location: Abu Qir - Tosson - Qesm El Montazah St., second Alexandria Egypt
# 2025-04-21 15:10:16,156 - INFO - Card 84 (The Higher Institute for Tourism, Hotels and Monuments Restoration - Abo Kir, Alexandria): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,159 - INFO - Card 85 (Higher Institute of Managerial Sciences - 6th of October): Found Location: City of Culture and Science - Block No. 3/51 AB - Central Axis - The eleventh district
# 2025-04-21 15:10:16,160 - INFO - Card 85 (Higher Institute of Managerial Sciences - 6th of October): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,164 - INFO - Card 86 (Al-Agamy Higher Institute for Administrative Sciences): Found Location: Al-Ajmi Abu Yousef as 19 tribal road Next to Abu Youssef Secondary Private School Alexandria Egypt
# 2025-04-21 15:10:16,166 - INFO - Card 86 (Al-Agamy Higher Institute for Administrative Sciences): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,169 - INFO - Card 87 (Commercial Technical Institute - Aswan): Found Location: Old Sheikha, Aswan, Aswan Aswan Egypt
# 2025-04-21 15:10:16,170 - INFO - Card 87 (Commercial Technical Institute - Aswan): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,173 - INFO - Card 88 (Higher Institute of Applied Arts - Fifth Settlement): Found Location: Gamal Abdel Nasser, the first of the new Cairo Cairo Egypt
# 2025-04-21 15:10:16,176 - INFO - Card 88 (Higher Institute of Applied Arts - Fifth Settlement): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,178 - INFO - Card 89 (New Cairo Institute for Administrative Sciences and Computer - First Settlement): Found Location: New Cairo - the first assembly - the seventh neighborhood - in front of the first assembly club next to the first assembly central Cairo Egypt
# 2025-04-21 15:10:16,183 - INFO - Card 89 (New Cairo Institute for Administrative Sciences and Computer - First Settlement): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,185 - INFO - Card 90 (Higher Institute of Management and Computer - Ras El-Bar): Found Location: Higher Institute of Management and Computer, Street 51, near Workers University, Ras al-Bar. Damietta Egypt
# 2025-04-21 15:10:16,187 - INFO - Card 90 (Higher Institute of Management and Computer - Ras El-Bar): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,191 - INFO - Card 91 (Higher Institute of Computers and Management Information Systems - First Settlement, New Cairo): Found Location: 2 east of the ring road, entrance to the first gathering, New Cairo, next to Mubarak Security Academy, in front of the bus stop, Zahraa Nasr City Cairo Egypt
# 2025-04-21 15:10:16,193 - INFO - Card 91 (Higher Institute of Computers and Management Information Systems - First Settlement, New Cairo): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,199 - INFO - Card 92 (Higher Institute of Computer Science and Management Technology - Sohag): Found Location: Salamouni, Akhmim Sohag Egypt
# 2025-04-21 15:10:16,201 - INFO - Card 92 (Higher Institute of Computer Science and Management Technology - Sohag): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,204 - INFO - Card 93 (Technical Nursing Institute - El Gouna): Found Location: Mohamed Ibrahim Kamel Street - El Gouna Red Sea Egypt
# 2025-04-21 15:10:16,206 - INFO - Card 93 (Technical Nursing Institute - El Gouna): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,208 - INFO - Card 94 (Future Higher Institute of Engineering - Fayoum): Found Location: Entrance to Damo, Fayoum, Damo, Fayoum Fayoum Egypt
# 2025-04-21 15:10:16,211 - INFO - Card 94 (Future Higher Institute of Engineering - Fayoum): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,214 - INFO - Card 95 (Al Madinah Higher Institute of Engineering and Technology - Shbrament): Found Location:
# 2025-04-21 15:10:16,217 - INFO - Card 95 (Al Madinah Higher Institute of Engineering and Technology - Shbrament): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,222 - INFO - Card 96 (New Cairo Technological University NCTU): Found Location:
# 2025-04-21 15:10:16,225 - INFO - Card 96 (New Cairo Technological University NCTU): Found Category (Fallback): Technological university
# 2025-04-21 15:10:16,229 - INFO - Card 97 (Higher Institute of Cooperative & Managerial Studies - Al-Muneera): Found Location: Al-Munirah - in front of Dar Al-Hikma, Al-Kasr Al-Aini Street Cairo Egypt
# 2025-04-21 15:10:16,232 - INFO - Card 97 (Higher Institute of Cooperative & Managerial Studies - Al-Muneera): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,236 - INFO - Card 98 (The Institute of Management, Secretarial and Computer of the Coptic Girls College): Found Location: Al Sarayat Street - Abbasiya. Cairo Egypt
# 2025-04-21 15:10:16,239 - INFO - Card 98 (The Institute of Management, Secretarial and Computer of the Coptic Girls College): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,242 - INFO - Card 99 (Valley Higher Institute of Engineering and Technology - Qalyubia): Found Location: The land of Ahmed Orabi Association - Kilo 26 Cairo-Ismailia Desert Road. Al Qalyubia Egypt
# 2025-04-21 15:10:16,245 - INFO - Card 99 (Valley Higher Institute of Engineering and Technology - Qalyubia): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,249 - INFO - Card 100 (Higher Institute of Social Service - Aswan (Qena Branch)): Found Location: Masaken Othman Road, Qena District Qena Egypt
# 2025-04-21 15:10:16,253 - INFO - Card 100 (Higher Institute of Social Service - Aswan (Qena Branch)): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,256 - INFO - Card 101 (Minia Higher Institute of Languages): Found Location: Minya Minya Egypt
# 2025-04-21 15:10:16,258 - INFO - Card 101 (Minia Higher Institute of Languages): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,262 - INFO - Card 102 (Higher Institute for Advanced Studies - Katameya): Found Location: Schools complex next to the Hunting Club and Maadi Sports Club in Katameya. Cairo Egypt
# 2025-04-21 15:10:16,265 - INFO - Card 102 (Higher Institute for Advanced Studies - Katameya): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,267 - INFO - Card 103 (El Shorouk Academy): Found Location: Palm suburb, El-Shorouk city, Suez Road Cairo Egypt
# 2025-04-21 15:10:16,268 - INFO - Card 103 (El Shorouk Academy): Found Category (Fallback): Academy
# 2025-04-21 15:10:16,271 - INFO - Card 104 (INSTITUTE OF AVIATION ENGINEERING & TECHNOLOGY Imbaba): Found Location: Airport, Imbaba, Giza Giza Egypt
# 2025-04-21 15:10:16,273 - INFO - Card 104 (INSTITUTE OF AVIATION ENGINEERING & TECHNOLOGY Imbaba): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,275 - INFO - Card 105 (Higher Institute for Administrative Sciences and Foreign Trade - Fifth Settlement): Found Location: Gamal Abdel Nasser, the first of the new Cairo Cairo Egypt
# 2025-04-21 15:10:16,277 - INFO - Card 105 (Higher Institute for Administrative Sciences and Foreign Trade - Fifth Settlement): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,278 - INFO - Card 106 (Alexandria Higher Institute of Engineering and Technology AIET): Found Location: Dr. Mohamed Aboul Fotouh Hehasb street, off Victor Amma Noel street, next to Mostafa Kamel Tunnel, Smouha Alexandria Egypt
# 2025-04-21 15:10:16,279 - INFO - Card 106 (Alexandria Higher Institute of Engineering and Technology AIET): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,283 - INFO - Card 107 (Higher Institute of Commercial and Computer Sciences - Arish): Found Location: The educational complex in Ismailia, Cairo-Ismailia Desert Road Building No. 1 Higher Institute of Commercial Sciences and Computer in Al-Arish, Ismailia headquarters Ismailia Egypt
# 2025-04-21 15:10:16,284 - INFO - Card 107 (Higher Institute of Commercial and Computer Sciences - Arish): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,288 - INFO - Card 108 (The Higher Institute for Advanced Administrative Sciences and Computers - Abu Al-Matamir, Al-Behaira): Found Location: Kilo 47 Alexandria-Cairo Desert Road Al Beheira Egypt
# 2025-04-21 15:10:16,290 - INFO - Card 108 (The Higher Institute for Advanced Administrative Sciences and Computers - Abu Al-Matamir, Al-Behaira): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,292 - INFO - Card 109 (The Intermediate Institute for Social Service - Aswan): Found Location: Aswan Aswan Egypt
# 2025-04-21 15:10:16,295 - INFO - Card 109 (The Intermediate Institute for Social Service - Aswan): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,299 - INFO - Card 110 (Salam Higher Institute of Engineering and Technology): Found Location: Shaarawi Shark, Baraka Al-Nasr, Division of Omar Bin Al-Khattab Cairo Egypt
# 2025-04-21 15:10:16,301 - INFO - Card 110 (Salam Higher Institute of Engineering and Technology): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,303 - INFO - Card 111 (Higher Institute for Qualitative Studies - Heliopolis): Found Location: 154 El Hegaz Square - Heliopolis. Cairo Egypt
# 2025-04-21 15:10:16,305 - INFO - Card 111 (Higher Institute for Qualitative Studies - Heliopolis): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,308 - INFO - Card 112 (Horus University HUE): Found Location: International Coastal Road, New Damietta Damietta Egypt
# 2025-04-21 15:10:16,309 - INFO - Card 112 (Horus University HUE): Found Category (Fallback): Private university
# 2025-04-21 15:10:16,312 - INFO - Card 113 (Higher Institute of Social Service - Nasr City, Cairo): Found Location: Mohamed Karim, Sixth Zone, Nasr City, Cairo Governorate Cairo Egypt
# 2025-04-21 15:10:16,314 - INFO - Card 113 (Higher Institute of Social Service - Nasr City, Cairo): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,317 - INFO - Card 114 (Thebes Higher Institute for Management and Information Technology - Saqqara, Haram): Found Location:
# 2025-04-21 15:10:16,318 - INFO - Card 114 (Thebes Higher Institute for Management and Information Technology - Saqqara, Haram): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,321 - INFO - Card 115 (Institute of Computing and Information Technology of Aviation and Aerospace in Imbaba): Found Location: Imbāba Airport Street Giza Egypt
# 2025-04-21 15:10:16,322 - INFO - Card 115 (Institute of Computing and Information Technology of Aviation and Aerospace in Imbaba): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,325 - INFO - Card 116 (Cairo Higher Institute of Engineering, Computer Science and Management - Albanfsg 2): Found Location: Second District, El-Banafseg Service Center (2), First Settlement New Cairo Egypt
# 2025-04-21 15:10:16,325 - INFO - Card 116 (Cairo Higher Institute of Engineering, Computer Science and Management - Albanfsg 2): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,329 - INFO - Card 117 (Higher Institute of Administrative Sciences - Belqas): Found Location: El-Kordoud, Stamouni Road, Belqas Dakahlia Egypt
# 2025-04-21 15:10:16,332 - INFO - Card 117 (Higher Institute of Administrative Sciences - Belqas): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,333 - INFO - Card 118 (Higher Institute for Hotel and Tourism Studies - New Damietta): Found Location: New Damietta City, Kafr Saad, Damietta Damietta Egypt
# 2025-04-21 15:10:16,336 - INFO - Card 118 (Higher Institute for Hotel and Tourism Studies - New Damietta): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,339 - INFO - Card 119 (Higher Institute of Social Service - Kafr El Sheikh): Found Location: Qism Kafr El-Shaikh, Kafr Al Sheikh Kafr El Sheikh Governorate Egypt
# 2025-04-21 15:10:16,341 - INFO - Card 119 (Higher Institute of Social Service - Kafr El Sheikh): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,342 - INFO - Card 120 (The Higher Institute for Tourism and Hotels - Alexandria (EGOTH)): Found Location: 31 Mostafa Abu Heif St. - Saba Pasha - Alexandria behind the Mercure Hotel. Alexandria Egypt
# 2025-04-21 15:10:16,345 - INFO - Card 120 (The Higher Institute for Tourism and Hotels - Alexandria (EGOTH)): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,348 - INFO - Card 121 (Intermediate Institute for Social Service - Garden City): Found Location: 8 El-Diwan St., Qasr El-Nil, Qasr El Nil Cairo Egypt
# 2025-04-21 15:10:16,350 - INFO - Card 121 (Intermediate Institute for Social Service - Garden City): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,353 - INFO - Card 122 (Commercial Technical Institute - Alexandria): Found Location: Ambrose and Muharram Bey, Department of Muharram Bey, Alexandria Alexandria
# 2025-04-21 15:10:16,357 - INFO - Card 122 (Commercial Technical Institute - Alexandria): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,359 - INFO - Card 123 (Higher Institute of Computer Science and Information Systems): Found Location: City of Culture and Science - Block No. 3/51 AB - Central Axis - The eleventh district Giza Egypt
# 2025-04-21 15:10:16,369 - INFO - Card 123 (Higher Institute of Computer Science and Information Systems): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,372 - INFO - Card 124 (Industrial Technical Institute - Quesna): Found Location: Kfour El-Raml, Quesna Center, Menoufia Menoufia Egypt
# 2025-04-21 15:10:16,375 - INFO - Card 124 (Industrial Technical Institute - Quesna): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,382 - INFO - Card 125 (Egypt Higher Institute for Trade and Accounts - Mansoura): Found Location: Mansoura - Ring Road Dakahlia Egypt
# 2025-04-21 15:10:16,385 - INFO - Card 125 (Egypt Higher Institute for Trade and Accounts - Mansoura): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,387 - INFO - Card 126 (Higher Institute of Social Service - Aswan): Found Location: Kasr El Hagar St., Downtown, Qism Aswan, Aswan Aswan Egypt
# 2025-04-21 15:10:16,391 - INFO - Card 126 (Higher Institute of Social Service - Aswan): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,393 - INFO - Card 127 (Industrial Technical Institute for Building Materials - Helwan): Found Location: Kafr El-Elw, Qism Helwan, Cairo Governorate Cairo Egypt
# 2025-04-21 15:10:16,410 - INFO - Card 127 (Industrial Technical Institute for Building Materials - Helwan): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,415 - INFO - Card 128 (Higher Institute of Engineering and Technology - Sohag): Found Location: Sohag district, Al Kawthar, Sohag Sohag Egypt
# 2025-04-21 15:10:16,417 - INFO - Card 128 (Higher Institute of Engineering and Technology - Sohag): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,421 - INFO - Card 129 (Industrial Technical Institute for Monuments Restoration - Luxor): Found Location: Al-Baghdadi, Luxor Luxor Egypt
# 2025-04-21 15:10:16,423 - INFO - Card 129 (Industrial Technical Institute for Monuments Restoration - Luxor): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,426 - INFO - Card 130 (Higher Institute of Languages - Mansoura): Found Location: Mansoura is the extension of the lower walk on the Mit Badr Khamis road, directly on the Nile Dakahlia Egypt
# 2025-04-21 15:10:16,428 - INFO - Card 130 (Higher Institute of Languages - Mansoura): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,430 - INFO - Card 131 (Hotel Technical Institute - Al-Matareya): Found Location: West, New Street, Masaken Al Mohandesin, Ain Shams, Cairo Governorate Cairo Egypt
# 2025-04-21 15:10:16,433 - INFO - Card 131 (Hotel Technical Institute - Al-Matareya): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,436 - INFO - Card 132 (Technical Institute for Irrigation, Drainage and Surveying - Al-Mataria): Found Location: Matareya Museum, Helmeya El-Naam, Ain Shams, Cairo Governorate Cairo Egypt
# 2025-04-21 15:10:16,439 - INFO - Card 132 (Technical Institute for Irrigation, Drainage and Surveying - Al-Mataria): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,442 - INFO - Card 133 (Higher Institute of Social Service - Alexandria): Found Location: 67 El Rassafa St. - Moharram Bey Alexandria Egypt
# 2025-04-21 15:10:16,444 - INFO - Card 133 (Higher Institute of Social Service - Alexandria): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,446 - INFO - Card 134 (Optical Industrial Technical Institute): Found Location: Dr. Ahmad Rish Rifai, Eastern Omrania, Omrania, Cairo Governorate Cairo Egypt
# 2025-04-21 15:10:16,449 - INFO - Card 134 (Optical Industrial Technical Institute): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,451 - INFO - Card 135 (Mansoura Higher Institute of Engineering and Technology MIET): Found Location: Damietta - Mansoura highway, next to Mansoura College schools. Dakahlia Egypt
# 2025-04-21 15:10:16,453 - INFO - Card 135 (Mansoura Higher Institute of Engineering and Technology MIET): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,457 - INFO - Card 136 (Higher Institute for Agricultural Cooperation and Extension - Assiut): Found Location: Second Hamra, Al-Fateh Center Assiut Egypt
# 2025-04-21 15:10:16,458 - INFO - Card 136 (Higher Institute for Agricultural Cooperation and Extension - Assiut): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,461 - INFO - Card 137 (Thebes Higher Institute of Engineering - Maadi): Found Location:
# 2025-04-21 15:10:16,463 - INFO - Card 137 (Thebes Higher Institute of Engineering - Maadi): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,465 - INFO - Card 138 (Commercial Technical Institute - Damietta): Found Location: New Damietta, Industrial Zone, in front of Shoman Factory Damietta Egypt
# 2025-04-21 15:10:16,467 - INFO - Card 138 (Commercial Technical Institute - Damietta): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,471 - INFO - Card 139 (Industrial Technical Institute - Mahalla al-Kubra): Found Location: The locality of Abu Ali Al-Qantara, Al-Mahalla Al-Kubra, Gharbia Al-Mahalla Al-Kubra Egypt
# 2025-04-21 15:10:16,473 - INFO - Card 139 (Industrial Technical Institute - Mahalla al-Kubra): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,475 - INFO - Card 140 (Commercial Technical Institute - Mansoura): Found Location: Mansoura (Section 2), Mansoura, Dakahlia Mansoura Egypt
# 2025-04-21 15:10:16,476 - INFO - Card 140 (Commercial Technical Institute - Mansoura): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,478 - INFO - Card 141 (Obour Higher Institute of Engineering and Technology): Found Location: Kilo 31 Cairo-Ismailia Desert Road Cairo Egypt
# 2025-04-21 15:10:16,480 - INFO - Card 141 (Obour Higher Institute of Engineering and Technology): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,483 - INFO - Card 142 (Higher Institute of Engineering and Technology - Beheira): Found Location: Kilo 47 Alexandria-Cairo Desert Road Al Beheira Egypt
# 2025-04-21 15:10:16,484 - INFO - Card 142 (Higher Institute of Engineering and Technology - Beheira): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,487 - INFO - Card 143 (Beni Suef Technological University BTU - The Egyptian Korean College of Industrial Technology and Energy): Found Location: First District - First Neighborhood - El Narges St. from Bayram El Tounsy Beni Suef Egypt
# 2025-04-21 15:10:16,489 - INFO - Card 143 (Beni Suef Technological University BTU - The Egyptian Korean College of Industrial Technology and Energy): Found Category (Fallback): Technological university
# 2025-04-21 15:10:16,492 - INFO - Card 144 (Industrial Technical Institute - Port Said): Found Location: Port Fouad, Port Saïd Port Saïd Egypt
# 2025-04-21 15:10:16,495 - INFO - Card 144 (Industrial Technical Institute - Port Said): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,497 - INFO - Card 145 (Technical Institute for Tourism and Hotels - Port Said): Found Location: almanakh, Port Said Port Said Egypt
# 2025-04-21 15:10:16,498 - INFO - Card 145 (Technical Institute for Tourism and Hotels - Port Said): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,499 - INFO - Card 146 (Commercial Technical Institute - Arish): Found Location: Section Three Al-Arish, North Sinai Al-Arish Egypt
# 2025-04-21 15:10:16,500 - INFO - Card 146 (Commercial Technical Institute - Arish): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,502 - INFO - Card 147 (Industrial Technical Institute for Irrigation, Drainage and Surveying - Assiut): Found Location: The second red, Al-Fateh Center, Assiut Assiut Egypt
# 2025-04-21 15:10:16,503 - INFO - Card 147 (Industrial Technical Institute for Irrigation, Drainage and Surveying - Assiut): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,504 - INFO - Card 148 (Commercial Technical Institute - Damanhour): Found Location: Desouk - Damanhour, Tamos, Qasim Damanhour, Beheira Damanhour Egypt
# 2025-04-21 15:10:16,505 - INFO - Card 148 (Commercial Technical Institute - Damanhour): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,508 - INFO - Card 149 (Commercial Technical Institute - Beni Suef): Found Location: Department of Beni Suef, Beni Suef, Beni Suef Governorate Beni Suef Egypt
# 2025-04-21 15:10:16,509 - INFO - Card 149 (Commercial Technical Institute - Beni Suef): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,511 - INFO - Card 150 (Delta Technological University DTU): Found Location: Quesna Menoufia Egypt
# 2025-04-21 15:10:16,513 - INFO - Card 150 (Delta Technological University DTU): Found Category (Fallback): Technological university
# 2025-04-21 15:10:16,515 - INFO - Card 151 (Commercial Technical Institute - Quesna): Found Location: Kfour El-Raml, Quesna Center, Menoufia Menoufia Egypt
# 2025-04-21 15:10:16,517 - INFO - Card 151 (Commercial Technical Institute - Quesna): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,519 - INFO - Card 152 (Higher Institute of Engineering and Technology - Burg Al Arab): Found Location: Soukra and Abu Hamad Basin, Department of Borg El Arab, Alexandria Borg El Arab Egypt
# 2025-04-21 15:10:16,521 - INFO - Card 152 (Higher Institute of Engineering and Technology - Burg Al Arab): Found Category (Fallback): High institute
# 2025-04-21 15:10:16,521 - INFO - Card 153 (Industrial Technical Institute - Bir al-Abd): Found Location: Bir al-Abd section, North Sinai Bir al-Abd Egypt
# 2025-04-21 15:10:16,523 - INFO - Card 153 (Industrial Technical Institute - Bir al-Abd): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,526 - INFO - Card 154 (Commercial Technical Institute - Sohag): Found Location: The Salmonite, Akhmeem Center, Sohag Sohag Egypt
# 2025-04-21 15:10:16,527 - INFO - Card 154 (Commercial Technical Institute - Sohag): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,529 - INFO - Card 155 (Commercial Technical Institute - Qena): Found Location: Commercial Technical Institute, Qena Department, Qena Qena Egypt
# 2025-04-21 15:10:16,531 - INFO - Card 155 (Commercial Technical Institute - Qena): Found Category (Fallback): Technology institute
# 2025-04-21 15:10:16,533 - INFO - Card 156 (Higher Institute of Islamic Studies): Found Location: Meet Aqabah Island, Agouza neighborhood, Giza Giza Egypt
# ...
# 2025-04-21 15:32:38,569 - INFO - Found 0 main program categories.
# 2025-04-21 15:32:38,570 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:32:38,572 - INFO - Finished processing detail page for: Chamber Sandikal Technical Institute of Fashion
# 2025-04-21 15:32:38,574 - INFO - --- Processing institution 290 of 303 ---
# 2025-04-21 15:32:38,574 - INFO - Scraping detail page for Merit University: https://study-in-egypt.gov.eg/categories/All/360/Merit-University
# 2025-04-21 15:32:41,938 - INFO - Name 'Merit University' confirmed.
# 2025-04-21 15:32:41,942 - INFO - Found Email: admisson@merit.edu.eg
# 2025-04-21 15:32:41,945 - INFO - Found Phone: 2001022110546
# 2025-04-21 15:32:41,953 - INFO - Found Year Built: 2020
# 2025-04-21 15:32:41,958 - INFO - Found Coordinator: Dr. ahmed elsayed
# 2025-04-21 15:32:41,961 - INFO - Found 1 amenities.
# 2025-04-21 15:32:41,965 - INFO - Found Description.
# 2025-04-21 15:32:41,965 - INFO - Extracting programs...
# 2025-04-21 15:32:41,967 - INFO - Found 1 main program categories.
# 2025-04-21 15:32:41,969 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:32:41,972 - INFO - Found 3 total programs. Creating flattened rows...
# 2025-04-21 15:32:41,973 - INFO - Finished processing detail page for: Merit University
# 2025-04-21 15:32:41,974 - INFO - --- Processing institution 291 of 303 ---
# 2025-04-21 15:32:41,975 - INFO - Scraping detail page for Sphinx University: https://study-in-egypt.gov.eg/categories/All/362/Sphinx-University
# 2025-04-21 15:32:45,404 - INFO - Name 'Sphinx University' confirmed.
# 2025-04-21 15:32:45,407 - INFO - Found Email: Info@Sphinx.edu.eg
# 2025-04-21 15:32:45,411 - INFO - Found Phone: 2001212222752
# 2025-04-21 15:32:45,420 - INFO - Found Year Built: 2019
# 2025-04-21 15:32:45,424 - INFO - Found Coordinator: Dr. Mansour Kabash
# 2025-04-21 15:32:45,426 - INFO - Found 1 amenities.
# 2025-04-21 15:32:45,432 - INFO - Found Description.
# 2025-04-21 15:32:45,433 - INFO - Extracting programs...
# 2025-04-21 15:32:45,436 - INFO - Found 1 main program categories.
# 2025-04-21 15:32:45,436 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:32:45,437 - INFO - Found 1 total programs. Creating flattened rows...
# 2025-04-21 15:32:45,439 - INFO - Finished processing detail page for: Sphinx University
# 2025-04-21 15:32:45,440 - INFO - --- Processing institution 292 of 303 ---
# 2025-04-21 15:32:45,441 - INFO - Scraping detail page for Higher Institute of Specific Studies - Giza: https://study-in-egypt.gov.eg/categories/All/102/Higher-Institute-of-Specific-Studies---Giza
# 2025-04-21 15:32:51,167 - INFO - Name 'Higher Institute of Specific Studies - Giza' confirmed.
# 2025-04-21 15:32:51,202 - INFO - Found Email: 000@Nomail
# 2025-04-21 15:32:51,229 - INFO - Found Phone: 2001010364130
# 2025-04-21 15:32:51,296 - INFO - Year Built not found.
# 2025-04-21 15:32:51,328 - INFO - Found Coordinator: NA
# 2025-04-21 15:32:51,367 - INFO - Amenities section empty.
# 2025-04-21 15:32:51,431 - INFO - Description panel empty.
# 2025-04-21 15:32:51,432 - INFO - Extracting programs...
# 2025-04-21 15:32:51,459 - INFO - Found 0 main program categories.
# 2025-04-21 15:32:51,460 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:32:51,460 - INFO - Finished processing detail page for: Higher Institute of Specific Studies - Giza
# 2025-04-21 15:32:51,461 - INFO - --- Processing institution 293 of 303 ---
# 2025-04-21 15:32:51,461 - INFO - Scraping detail page for Damietta University: https://study-in-egypt.gov.eg/categories/All/16/Damietta-University
# 2025-04-21 15:32:57,098 - INFO - Name 'Damietta University' confirmed.
# 2025-04-21 15:32:57,104 - INFO - Found Email: portal@du.edu.eg
# 2025-04-21 15:32:57,109 - INFO - Found Phone: 201093409270
# 2025-04-21 15:32:57,170 - INFO - Found Year Built: 2012
# 2025-04-21 15:32:57,208 - INFO - Found Coordinator: Prof. Dr ./ Mohammed Hamed Bahnasawy - Dr . Mona Ali Elmanshy
# 2025-04-21 15:32:57,211 - INFO - Found 1 amenities.
# 2025-04-21 15:32:57,277 - INFO - Found Description.
# 2025-04-21 15:32:57,279 - INFO - Extracting programs...
# 2025-04-21 15:32:57,315 - INFO - Found 4 main program categories.
# 2025-04-21 15:32:57,316 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:32:57,328 - INFO - Processing Category: Academic Postgraduate
# 2025-04-21 15:32:57,362 - INFO - Processing Category: Credit Hours Programs
# 2025-04-21 15:32:57,419 - INFO - Processing Category: Special Programs
# 2025-04-21 15:32:57,429 - INFO - Found 519 total programs. Creating flattened rows...
# 2025-04-21 15:32:57,430 - INFO - Finished processing detail page for: Damietta University
# 2025-04-21 15:32:57,431 - INFO - --- Processing institution 294 of 303 ---
# 2025-04-21 15:32:57,432 - INFO - Scraping detail page for Suez University: https://study-in-egypt.gov.eg/categories/All/74/Suez-University
# 2025-04-21 15:33:03,029 - INFO - Name 'Suez University' confirmed.
# 2025-04-21 15:33:03,036 - INFO - Found Email: President@suezuniv.edu.eg
# 2025-04-21 15:33:03,040 - INFO - Found Phone: 20623523773
# 2025-04-21 15:33:03,116 - INFO - Found Year Built: 2012
# 2025-04-21 15:33:03,159 - INFO - Found Coordinator: Dr. Adel Mohamed Salem Ragab
# 2025-04-21 15:33:03,165 - INFO - Found 1 amenities.
# 2025-04-21 15:33:03,212 - INFO - Found Description.
# 2025-04-21 15:33:03,213 - INFO - Extracting programs...
# 2025-04-21 15:33:03,252 - INFO - Found 4 main program categories.
# 2025-04-21 15:33:03,253 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:33:03,268 - INFO - Processing Category: Academic Postgraduate
# 2025-04-21 15:33:03,357 - INFO - Processing Category: Credit Hours Programs
# 2025-04-21 15:33:03,371 - INFO - Processing Category: Special Programs
# 2025-04-21 15:33:03,379 - INFO - Found 387 total programs. Creating flattened rows...
# 2025-04-21 15:33:03,380 - INFO - Finished processing detail page for: Suez University
# 2025-04-21 15:33:03,381 - INFO - --- Processing institution 295 of 303 ---
# 2025-04-21 15:33:03,382 - INFO - Scraping detail page for Al-Salam University: https://study-in-egypt.gov.eg/categories/All/361/Al-Salam-University
# 2025-04-21 15:33:06,730 - INFO - Name 'Al-Salam University' confirmed.
# 2025-04-21 15:33:06,733 - INFO - Found Email: admission@sue.edu.eg
# 2025-04-21 15:33:06,735 - INFO - Found Phone: 20 01203008901
# 2025-04-21 15:33:06,749 - INFO - Found Year Built: 2018
# 2025-04-21 15:33:06,753 - INFO - Found Coordinator: Prof.Dr Mohamed Sakr
# 2025-04-21 15:33:06,755 - INFO - Amenities section empty.
# 2025-04-21 15:33:06,761 - INFO - Found Description.
# 2025-04-21 15:33:06,762 - INFO - Extracting programs...
# 2025-04-21 15:33:06,765 - INFO - Found 0 main program categories.
# 2025-04-21 15:33:06,766 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:33:06,767 - INFO - Finished processing detail page for: Al-Salam University
# 2025-04-21 15:33:06,768 - INFO - --- Processing institution 296 of 303 ---
# 2025-04-21 15:33:06,769 - INFO - Scraping detail page for Tanta University: https://study-in-egypt.gov.eg/categories/All/365/Tanta-University
# 2025-04-21 15:33:12,782 - INFO - Name 'Tanta University' confirmed.
# 2025-04-21 15:33:12,786 - INFO - Found Email: iss@unv.tanta.edu.eg
# 2025-04-21 15:33:12,790 - INFO - Found Phone: 201064844906
# 2025-04-21 15:33:12,839 - INFO - Found Year Built: 1972
# 2025-04-21 15:33:12,868 - INFO - Found Coordinator: Dr.Mahmoud Shakal
# 2025-04-21 15:33:12,871 - INFO - Found 1 amenities.
# 2025-04-21 15:33:12,909 - INFO - Found Description.
# 2025-04-21 15:33:12,909 - INFO - Extracting programs...
# 2025-04-21 15:33:12,935 - INFO - Found 4 main program categories.
# 2025-04-21 15:33:12,936 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:33:12,947 - INFO - Processing Category: Academic Postgraduate
# 2025-04-21 15:33:13,042 - INFO - Processing Category: Credit Hours Programs
# 2025-04-21 15:33:13,069 - INFO - Processing Category: Special Programs
# 2025-04-21 15:33:13,071 - INFO - Found 359 total programs. Creating flattened rows...
# 2025-04-21 15:33:13,073 - INFO - Finished processing detail page for: Tanta University
# 2025-04-21 15:33:13,074 - INFO - --- Processing institution 297 of 303 ---
# 2025-04-21 15:33:13,075 - INFO - Scraping detail page for Giza Higher Institute of Engineering and Technology - Tomah: https://study-in-egypt.gov.eg/categories/All/106/Giza-Higher-Institute-of-Engineering-and-Technology---Tomah
# 2025-04-21 15:33:16,610 - INFO - Name 'Giza Higher Institute of Engineering and Technology - Tomah' confirmed.
# 2025-04-21 15:33:16,612 - INFO - Found Email: info@gei.edu.eg
# 2025-04-21 15:33:16,613 - INFO - Found Phone: 2001113277797
# 2025-04-21 15:33:16,623 - INFO - Found Year Built: 2007
# 2025-04-21 15:33:16,626 - INFO - Found Coordinator: NA
# 2025-04-21 15:33:16,628 - INFO - Amenities section empty.
# 2025-04-21 15:33:16,631 - INFO - Description panel empty.
# 2025-04-21 15:33:16,632 - INFO - Extracting programs...
# 2025-04-21 15:33:16,634 - INFO - Found 0 main program categories.
# 2025-04-21 15:33:16,635 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:33:16,635 - INFO - Finished processing detail page for: Giza Higher Institute of Engineering and Technology - Tomah
# 2025-04-21 15:33:16,636 - INFO - --- Processing institution 298 of 303 ---
# 2025-04-21 15:33:16,636 - INFO - Scraping detail page for University of Hertfordshire's: https://study-in-egypt.gov.eg/categories/All/363/University-of-Hertfordshire's
# 2025-04-21 15:33:20,093 - INFO - Name 'University of Hertfordshire's' confirmed.
# 2025-04-21 15:33:20,098 - INFO - Found Email: g.hazem@gaf.edu.eg
# 2025-04-21 15:33:20,100 - INFO - Found Phone: 2016192
# 2025-04-21 15:33:20,112 - INFO - Found Year Built: 2019
# 2025-04-21 15:33:20,117 - INFO - Found Coordinator: Mrs. Ghada Hazen
# 2025-04-21 15:33:20,119 - INFO - Amenities section empty.
# 2025-04-21 15:33:20,123 - INFO - Found Description.
# 2025-04-21 15:33:20,124 - INFO - Extracting programs...
# 2025-04-21 15:33:20,127 - INFO - Found 1 main program categories.
# 2025-04-21 15:33:20,129 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:33:20,129 - INFO - Found 1 total programs. Creating flattened rows...
# 2025-04-21 15:33:20,131 - INFO - Finished processing detail page for: University of Hertfordshire's
# 2025-04-21 15:33:20,132 - INFO - --- Processing institution 299 of 303 ---
# 2025-04-21 15:33:20,133 - INFO - Scraping detail page for Higher Institute of Social Service - 6th of October: https://study-in-egypt.gov.eg/categories/All/108/Higher-Institute-of-Social-Service---6th-of-October
# 2025-04-21 15:33:24,095 - INFO - Name 'Higher Institute of Social Service - 6th of October' confirmed.
# 2025-04-21 15:33:24,102 - INFO - Found Email: o6i@csi.edu.eg
# 2025-04-21 15:33:24,109 - INFO - Found Phone: 200222660000
# 2025-04-21 15:33:24,130 - INFO - Found Year Built: 1994
# 2025-04-21 15:33:24,138 - INFO - Found Coordinator: NA
# 2025-04-21 15:33:24,145 - INFO - Amenities section empty.
# 2025-04-21 15:33:24,156 - INFO - Description panel empty.
# 2025-04-21 15:33:24,157 - INFO - Extracting programs...
# 2025-04-21 15:33:24,164 - INFO - Found 0 main program categories.
# 2025-04-21 15:33:24,165 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:33:24,166 - INFO - Finished processing detail page for: Higher Institute of Social Service - 6th of October
# 2025-04-21 15:33:24,167 - INFO - --- Processing institution 300 of 303 ---
# 2025-04-21 15:33:24,167 - INFO - Scraping detail page for Higher Institute for Advanced Studies - Al-Haram: https://study-in-egypt.gov.eg/categories/All/101/Higher-Institute-for-Advanced-Studies---Al-Haram
# 2025-04-21 15:33:34,222 - INFO - Name 'Higher Institute for Advanced Studies - Al-Haram' confirmed.
# 2025-04-21 15:33:34,318 - INFO - Found Email: 000@Nomail
# 2025-04-21 15:33:34,394 - INFO - Found Phone: 2003 3844030
# 2025-04-21 15:33:34,630 - INFO - Found Year Built: 1995
# 2025-04-21 15:33:34,716 - INFO - Found Coordinator: NA
# 2025-04-21 15:33:34,787 - INFO - Amenities section empty.
# 2025-04-21 15:33:34,942 - INFO - Description panel empty.
# 2025-04-21 15:33:34,944 - INFO - Extracting programs...
# 2025-04-21 15:33:35,026 - INFO - Found 0 main program categories.
# 2025-04-21 15:33:35,028 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:33:35,029 - INFO - Finished processing detail page for: Higher Institute for Advanced Studies - Al-Haram
# 2025-04-21 15:33:35,031 - INFO - --- Processing institution 301 of 303 ---
# 2025-04-21 15:33:35,032 - INFO - Scraping detail page for European Universities in Egypt: https://study-in-egypt.gov.eg/categories/All/364/European-Universities-in-Egypt
# 2025-04-21 15:33:38,374 - INFO - Name 'European Universities in Egypt' confirmed.
# 2025-04-21 15:33:38,380 - INFO - Found Email: info@eue.edu.eg
# 2025-04-21 15:33:38,384 - INFO - Found Phone: 20 +20 1050122335
# 2025-04-21 15:33:38,399 - INFO - Found Year Built: 2021
# 2025-04-21 15:33:38,406 - INFO - Found Coordinator: Pr : Mahmoud Hachem Abdelkader
# 2025-04-21 15:33:38,410 - INFO - Amenities section empty.
# 2025-04-21 15:33:38,418 - INFO - Found Description.
# 2025-04-21 15:33:38,419 - INFO - Extracting programs...
# 2025-04-21 15:33:38,424 - INFO - Found 0 main program categories.
# 2025-04-21 15:33:38,425 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:33:38,426 - INFO - Finished processing detail page for: European Universities in Egypt
# 2025-04-21 15:33:38,427 - INFO - --- Processing institution 302 of 303 ---
# 2025-04-21 15:33:38,428 - INFO - Scraping detail page for Higher Institute of Media and Mass Communication - 6th of October: https://study-in-egypt.gov.eg/categories/All/109/Higher-Institute-of-Media-and-Mass-Communication---6th-of-October
# 2025-04-21 15:33:42,411 - INFO - Name 'Higher Institute of Media and Mass Communication - 6th of October' confirmed.
# 2025-04-21 15:33:42,424 - INFO - Found Email: o6i@csi.edu.eg
# 2025-04-21 15:33:42,437 - INFO - Found Phone: 200222660000
# 2025-04-21 15:33:42,462 - INFO - Found Year Built: 1994
# 2025-04-21 15:33:42,478 - INFO - Found Coordinator: NA
# 2025-04-21 15:33:42,489 - INFO - Amenities section empty.
# 2025-04-21 15:33:42,509 - INFO - Description panel empty.
# 2025-04-21 15:33:42,509 - INFO - Extracting programs...
# 2025-04-21 15:33:42,520 - INFO - Found 0 main program categories.
# 2025-04-21 15:33:42,522 - INFO - No programs found for this university. Adding single row with base details.
# 2025-04-21 15:33:42,523 - INFO - Finished processing detail page for: Higher Institute of Media and Mass Communication - 6th of October
# 2025-04-21 15:33:42,524 - INFO - --- Processing institution 303 of 303 ---
# 2025-04-21 15:33:42,525 - INFO - Scraping detail page for Galala University GU: https://study-in-egypt.gov.eg/categories/All/88/Galala-University-GU
# 2025-04-21 15:33:46,451 - INFO - Name 'Galala University GU' confirmed.
# 2025-04-21 15:33:46,456 - INFO - Found Email: info@gu.edu.eg
# 2025-04-21 15:33:46,461 - INFO - Found Phone: 20
# 2025-04-21 15:33:46,483 - INFO - Year Built not found.
# 2025-04-21 15:33:46,492 - INFO - Found Coordinator:
# 2025-04-21 15:33:46,494 - INFO - Found 1 amenities.
# 2025-04-21 15:33:46,505 - INFO - Found Description.
# 2025-04-21 15:33:46,505 - INFO - Extracting programs...
# 2025-04-21 15:33:46,512 - INFO - Found 1 main program categories.
# 2025-04-21 15:33:46,513 - INFO - Processing Category: Academic Undergraduate
# 2025-04-21 15:33:46,533 - INFO - Found 75 total programs. Creating flattened rows...
# 2025-04-21 15:33:46,534 - INFO - Finished processing detail page for: Galala University GU
# 2025-04-21 15:33:46,535 - INFO - Finished scraping detail pages.
# 2025-04-21 15:33:46,536 - INFO - Attempting to save 17581 rows to egypt_institutions_programs_flattened.csv
# 2025-04-21 15:33:49,033 - INFO - Data successfully saved to egypt_institutions_programs_flattened.csv
# 2025-04-21 15:33:49,034 - INFO - --- Scraper Finished ---
